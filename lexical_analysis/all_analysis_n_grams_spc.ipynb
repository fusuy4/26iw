# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_E_utt = pd.read_csv("combined_utt_sent_E.csv")
df_T_utt = pd.read_csv("combined_utt_sent_T.csv")
df_M_utt = pd.read_csv("combined_utt_sent_M.csv")
# Out:
# /var/folders/7t/rp_1dcrj5nv_nqhf5_82lk3h0000gn/T/ipykernel_18584/298430867.py:1: DtypeWarning: Columns (0: top_level_comment) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_E_utt = pd.read_csv("combined_utt_sent_E.csv")
# /var/folders/7t/rp_1dcrj5nv_nqhf5_82lk3h0000gn/T/ipykernel_18584/298430867.py:2: DtypeWarning: Columns (0: top_level_comment) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_T_utt = pd.read_csv("combined_utt_sent_T.csv")
# /var/folders/7t/rp_1dcrj5nv_nqhf5_82lk3h0000gn/T/ipykernel_18584/298430867.py:3: DtypeWarning: Columns (0: top_level_comment) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_M_utt = pd.read_csv("combined_utt_sent_M.csv")

# %% [markdown]
# ### Top X N-grams

# %%
import re
import nltk
import unicodedata
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('punkt_tab')
nltk.download('stopwords')

wnl = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yusufabdelnur/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/yusufabdelnur/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/yusufabdelnur/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yusufabdelnur/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# pos (str) – The Part Of Speech tag. 
# Valid options are 
#   “n” for nouns, “v” for verbs, “a” for adjectives, 
#   “r” for adverbs and “s” for satellite adjectives.

def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return "a"
    elif treebank_tag.startswith('V'):
        return "v"
    elif treebank_tag.startswith('N'):
        return "n"
    elif treebank_tag.startswith('R'):
        return "r"
    else:
        return 'n'

# %%
stop_words = (stopwords.words('english'))

extra_stopwords = [
    "like","get","got","would","one","time","really",
    "people","think","know","see","also","even","still",
    "im","dont","cant","could","us","go","going","back",
    "game","team","play","played","playing", "make"
]

domain_specific_stopwords = [
    "doom", "destiny", "star", "wars", "battlefront", "splatoon", 
    "gw", "garden", "warfare" "gw2", "gw3", "cod", "call", "of", "duty",
    "black", "ops", "remove", "post", "automaticly", "performed", "flair", "removed"
]

stop_words = stop_words + domain_specific_stopwords + extra_stopwords

# %%
def clean_text(text):
    text = str(text)

    text = unicodedata.normalize("NFKD", text)
    text = text.encode("ascii", "ignore").decode("utf-8", "ignore")

    text = text.lower()

    text = re.sub(r"http\S+|www\S+", " URL ", text)
    text = re.sub(r"\d+", " NUM ", text)

    text = text.replace("\n", " ").replace("\r", " ")
    text = re.sub(r"\s+", " ", text).strip()

    return text

# %%
def tokenize(text):
    tokens = []

    for token in nltk.pos_tag(word_tokenize(text)):
        wrd = token[0]
        pos = token[1]

        if wrd.isalpha() and len(wrd) > 2:
            lemma = wnl.lemmatize(wrd, get_wordnet_pos(pos))

            if lemma not in stop_words:
                tokens.append(lemma)

    return tokens

# %%
from collections import Counter

def get_ngrams(df, text_col="text", top_n=100):
    unigram_counter = Counter()
    bigram_counter = Counter()

    texts = df[text_col].dropna()

    for text in texts:
        clean = clean_text(text)      
        tokens = tokenize(clean)      

        unigram_counter.update(tokens)
        bigram_counter.update(zip(tokens, tokens[1:]))
    
    return (
        unigram_counter.most_common(top_n),
        bigram_counter.most_common(top_n),
    )

# %%
def plot_ngrams(unigrams, bigrams, rating=""):
    
    words, counts = zip(*unigrams)

    plt.figure()
    plt.bar(words[1:20], counts[1:20])
    plt.xticks(rotation=45)
    plt.title(f"Top Unigrams - {rating} Rated")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

    bigram_labels = [" ".join(bg) for bg, _ in bigrams]
    bigram_counts = [count for _, count in bigrams]

    plt.figure()
    plt.bar(bigram_labels[1:20], bigram_counts[1:20])
    plt.xticks(rotation=45)
    plt.title(f"Top Bigrams - {rating} Rated")
    plt.ylabel("Frequency")
    plt.tight_layout()
    plt.show()

# %%
def plot_ngrams_hor(unigrams, bigrams, rating=""):
    
    def plot_barh(labels, counts, title):
        plt.figure()
        plt.barh(labels, counts)
        plt.xlabel("Frequency")
        plt.title(title)
        plt.gca().invert_yaxis() 
        plt.tight_layout()
        plt.show()

    words, counts = zip(*unigrams)
    plot_barh(words, counts, f"Top Unigrams - {rating} Rated")

    bigram_labels = [" ".join(bg) for bg, _ in bigrams]
    bigram_counts = [count for _, count in bigrams]
    plot_barh(bigram_labels, bigram_counts, f"Top Bigrams - {rating} Rated")

# %% [markdown]
# Plotting unigrams and bigrams without removing special tokens (showing how num is an interesting quantifier)

# %%
unigrams_M, bigrams_M = get_ngrams(df_M_utt)

print("Top M unigrams:", unigrams_M)
print("Top M bigrams:", bigrams_M)
# Out:
# Top M unigrams: [('NUM', 227221), ('use', 33503), ('make', 33157), ('kill', 25032), ('say', 22216), ('map', 21233), ('URL', 20365), ('well', 20050), ('want', 19155), ('weapon', 18908), ('look', 18569), ('try', 18467), ('player', 18110), ('much', 17429), ('thing', 17385), ('way', 15835), ('take', 15302), ('run', 15006), ('work', 14719), ('need', 14690), ('new', 14194), ('gun', 14064), ('find', 13354), ('first', 13290), ('level', 12365), ('come', 12118), ('give', 11812), ('lot', 11770), ('something', 11741), ('pretty', 11648), ('feel', 11558), ('point', 11490), ('bad', 11413), ('though', 11393), ('right', 11201), ('every', 11006), ('never', 10999), ('sure', 10506), ('since', 10253), ('actually', 10150), ('mean', 10107), ('guy', 9925), ('love', 9833), ('start', 9602), ('hell', 9323), ('seem', 9320), ('enemy', 9000), ('around', 8862), ('day', 8800), ('yeah', 8750), ('fun', 8746), ('fuck', 8618), ('always', 8618), ('maybe', 8346), ('great', 8345), ('long', 8316), ('shit', 8286), ('mode', 8098), ('demon', 7954), ('probably', 7926), ('someone', 7861), ('drop', 7848), ('issue', 7759), ('happen', 7705), ('keep', 7694), ('best', 7664), ('problem', 7604), ('add', 7560), ('last', 7486), ('buy', 7423), ('high', 7309), ('many', 7232), ('help', 7196), ('video', 7051), ('thanks', 7040), ('hard', 7016), ('change', 6999), ('different', 6935), ('anything', 6870), ('two', 6752), ('multiplayer', 6752), ('put', 6701), ('lol', 6685), ('end', 6683), ('hit', 6576), ('year', 6513), ('mod', 6508), ('easy', 6461), ('shot', 6355), ('might', 6329), ('everyone', 6324), ('without', 6228), ('already', 6130), ('anyone', 6122), ('sound', 6122), ('let', 6058), ('match', 6053), ('reason', 5998), ('far', 5984), ('old', 5862)]
# Top M bigrams: [(('NUM', 'NUM'), 51834), (('NUM', 'kill'), 3528), (('supply', 'drop'), 3000), (('NUM', 'fps'), 2540), (('NUM', 'year'), 2300), (('NUM', 'hour'), 2252), (('pretty', 'much'), 2249), (('level', 'NUM'), 2210), (('NUM', 'second'), 1954), (('NUM', 'day'), 1661), (('season', 'pas'), 1644), (('NUM', 'minute'), 1637), (('make', 'sense'), 1628), (('dark', 'matter'), 1608), (('glory', 'kill'), 1563), (('around', 'NUM'), 1513), (('kill', 'NUM'), 1498), (('single', 'player'), 1483), (('make', 'sure'), 1466), (('use', 'NUM'), 1422), (('aim', 'assist'), 1421), (('NUM', 'player'), 1354), (('take', 'NUM'), 1350), (('anyone', 'else'), 1300), (('since', 'NUM'), 1268), (('say', 'NUM'), 1249), (('rapid', 'fire'), 1225), (('pretty', 'sure'), 1202), (('NUM', 'shot'), 1151), (('run', 'NUM'), 1150), (('map', 'NUM'), 1139), (('NUM', 'URL'), 1121), (('NUM', 'point'), 1120), (('last', 'night'), 1115), (('dead', 'silence'), 1102), (('amp', 'NUM'), 1082), (('URL', 'URL'), 1054), (('quake', 'NUM'), 1044), (('run', 'around'), 1030), (('NUM', 'map'), 1003), (('URL', 'NUM'), 979), (('care', 'package'), 972), (('gtx', 'NUM'), 956), (('NUM', 'use'), 944), (('rip', 'tear'), 930), (('long', 'barrel'), 916), (('every', 'single'), 906), (('prestige', 'NUM'), 895), (('melee', 'weapon'), 877), (('least', 'NUM'), 859), (('make', 'NUM'), 849), (('NUM', 'month'), 840), (('NUM', 'level'), 836), (('new', 'weapon'), 831), (('fast', 'hand'), 822), (('rocket', 'launcher'), 812), (('long', 'range'), 799), (('super', 'shotgun'), 795), (('NUM', 'make'), 785), (('drop', 'NUM'), 780), (('year', 'old'), 776), (('close', 'range'), 761), (('shot', 'kill'), 757), (('first', 'NUM'), 733), (('blops', 'NUM'), 731), (('well', 'NUM'), 728), (('NUM', 'prestige'), 722), (('NUM', 'weapon'), 717), (('assault', 'rifle'), 703), (('NUM', 'key'), 684), (('last', 'NUM'), 679), (('work', 'well'), 678), (('day', 'NUM'), 677), (('player', 'NUM'), 676), (('come', 'NUM'), 661), (('buy', 'NUM'), 657), (('maybe', 'NUM'), 655), (('xbox', 'NUM'), 648), (('NUM', 'amp'), 643), (('lag', 'lag'), 640), (('NUM', 'run'), 638), (('NUM', 'well'), 638), (('NUM', 'first'), 637), (('year', 'ago'), 636), (('NUM', 'spm'), 632), (('halo', 'NUM'), 628), (('NUM', 'win'), 626), (('win', 'NUM'), 625), (('every', 'NUM'), 625), (('high', 'caliber'), 620), (('need', 'NUM'), 619), (('feel', 'free'), 618), (('level', 'design'), 618), (('fire', 'rate'), 616), (('everyone', 'else'), 613), (('master', 'prestige'), 611), (('start', 'NUM'), 610), (('little', 'bit'), 609), (('NUM', 'town'), 600), (('NUM', 'come'), 597)]

# %%
plot_ngrams(unigrams_M[1:], bigrams_M[1:], rating="M")

# %%
plot_ngrams_hor(unigrams_M[1:20], bigrams_M[1:20], "M")

# %%
unigrams_T, bigrams_T = get_ngrams(df_T_utt)

print("Top T unigrams:", unigrams_T)
print("Top T bigrams:", bigrams_T)
# Out:
# Top T unigrams: [('NUM', 197218), ('make', 33547), ('use', 25362), ('say', 24822), ('want', 24232), ('look', 22502), ('player', 19868), ('well', 19566), ('thing', 18157), ('URL', 17670), ('much', 17304), ('take', 16919), ('need', 16513), ('new', 16506), ('way', 16325), ('map', 15004), ('try', 14857), ('kill', 14802), ('hero', 14337), ('first', 13936), ('give', 13892), ('come', 13560), ('work', 13505), ('clan', 12686), ('point', 12628), ('buy', 12259), ('right', 12181), ('feel', 12154), ('find', 11703), ('something', 11411), ('weapon', 11324), ('level', 11254), ('lot', 11154), ('mean', 11082), ('run', 11038), ('dlc', 10921), ('war', 10799), ('sure', 10698), ('though', 10694), ('raid', 10656), ('mode', 10656), ('fun', 10627), ('pretty', 10432), ('every', 10177), ('actually', 10157), ('never', 10077), ('content', 9913), ('bad', 9660), ('since', 9598), ('yeah', 9523), ('love', 9482), ('day', 9210), ('seem', 8936), ('add', 8734), ('change', 8675), ('start', 8550), ('around', 8490), ('drop', 8467), ('maybe', 8195), ('keep', 8044), ('already', 7940), ('great', 7922), ('last', 7850), ('hour', 7846), ('everyone', 7805), ('many', 7784), ('character', 7712), ('week', 7683), ('probably', 7667), ('guy', 7636), ('two', 7597), ('help', 7583), ('release', 7471), ('always', 7445), ('anything', 7382), ('lol', 7360), ('base', 7334), ('someone', 7285), ('long', 7173), ('different', 7102), ('dice', 7041), ('wait', 7031), ('happen', 6958), ('best', 6854), ('year', 6841), ('system', 6745), ('problem', 6743), ('end', 6736), ('let', 6635), ('beta', 6604), ('hope', 6548), ('gun', 6505), ('join', 6445), ('enough', 6399), ('anyone', 6396), ('yes', 6386), ('match', 6350), ('pay', 6338), ('damage', 6301), ('issue', 6292)]
# Top T bigrams: [(('NUM', 'NUM'), 32168), (('NUM', 'hour'), 4575), (('level', 'NUM'), 2898), (('NUM', 'year'), 2637), (('season', 'pas'), 2520), (('make', 'sense'), 2070), (('NUM', 'player'), 2037), (('pretty', 'much'), 2021), (('clone', 'war'), 1935), (('walker', 'assault'), 1854), (('NUM', 'minute'), 1835), (('NUM', 'second'), 1712), (('battlefield', 'NUM'), 1663), (('public', 'event'), 1517), (('around', 'NUM'), 1447), (('NUM', 'kill'), 1385), (('NUM', 'day'), 1373), (('take', 'NUM'), 1361), (('loot', 'box'), 1357), (('pretty', 'sure'), 1326), (('power', 'level'), 1315), (('space', 'battle'), 1260), (('light', 'level'), 1221), (('amp', 'NUM'), 1204), (('say', 'NUM'), 1188), (('use', 'NUM'), 1164), (('NUM', 'month'), 1157), (('last', 'night'), 1156), (('make', 'sure'), 1140), (('NUM', 'fps'), 1132), (('anyone', 'else'), 1117), (('fighter', 'squadron'), 1084), (('NUM', 'map'), 1070), (('NUM', 'week'), 1046), (('URL', 'URL'), 1017), (('NUM', 'person'), 1011), (('amp', 'nbsp'), 1008), (('single', 'player'), 998), (('URL', 'NUM'), 978), (('make', 'NUM'), 972), (('feel', 'free'), 965), (('pay', 'NUM'), 923), (('look', 'forward'), 912), (('year', 'NUM'), 904), (('run', 'around'), 904), (('loot', 'crate'), 897), (('NUM', 'clan'), 895), (('least', 'NUM'), 886), (('please', 'contact'), 861), (('day', 'NUM'), 858), (('contact', 'moderator'), 855), (('NUM', 'look'), 845), (('buy', 'NUM'), 838), (('NUM', 'light'), 822), (('jump', 'pack'), 821), (('NUM', 'question'), 820), (('question', 'concern'), 813), (('kill', 'NUM'), 795), (('since', 'NUM'), 792), (('drop', 'NUM'), 792), (('hero', 'villain'), 792), (('player', 'base'), 789), (('subreddit', 'NUM'), 773), (('join', 'clan'), 768), (('bot', 'action'), 766), (('action', 'perform'), 766), (('perform', 'automatically'), 765), (('automatically', 'please'), 765), (('moderator', 'subreddit'), 765), (('server', 'browser'), 756), (('every', 'single'), 754), (('player', 'NUM'), 753), (('NUM', 'hero'), 749), (('NUM', 'credit'), 738), (('NUM', 'URL'), 736), (('give', 'NUM'), 735), (('everyone', 'else'), 732), (('run', 'NUM'), 728), (('swbf', 'NUM'), 716), (('NUM', 'make'), 715), (('submission', 'automatically'), 715), (('sorry', 'submission'), 706), (('hit', 'NUM'), 705), (('NUM', 'new'), 703), (('clan', 'NUM'), 701), (('look', 'clan'), 699), (('hand', 'cannon'), 694), (('outer', 'rim'), 694), (('year', 'old'), 681), (('NUM', 'point'), 679), (('NUM', 'character'), 674), (('first', 'person'), 673), (('first', 'NUM'), 671), (('tie', 'fighter'), 665), (('lvl', 'NUM'), 661), (('spend', 'NUM'), 660), (('NUM', 'shot'), 656), (('iron', 'banner'), 652), (('NUM', 'member'), 638), (('need', 'NUM'), 637)]

# %%
plot_ngrams(unigrams_T[1:], bigrams_T[1:], "T")

# %%
plot_ngrams_hor(unigrams_T[1:20], bigrams_T[1:20], "T")

# %%
unigrams_E, bigrams_E = get_ngrams(df_E_utt)

print("Top E unigrams:", unigrams_E)
print("Top E bigrams:", bigrams_E)
# Out:
# Top E unigrams: [('NUM', 172565), ('use', 33997), ('make', 31423), ('well', 20790), ('player', 20615), ('say', 20245), ('URL', 19410), ('much', 18532), ('need', 17799), ('try', 17786), ('want', 17608), ('weapon', 17262), ('take', 17078), ('damage', 16598), ('character', 16135), ('thing', 16096), ('way', 15969), ('kill', 15729), ('look', 13891), ('ink', 13605), ('point', 13272), ('though', 12953), ('rank', 12931), ('match', 12748), ('new', 12435), ('lot', 12317), ('map', 12077), ('right', 11893), ('give', 11843), ('work', 11822), ('first', 11722), ('pretty', 11440), ('actually', 11440), ('zombie', 11347), ('come', 11304), ('bad', 11153), ('find', 11078), ('win', 11022), ('mean', 11016), ('ability', 10875), ('since', 10857), ('range', 10831), ('something', 10663), ('mode', 10343), ('feel', 10171), ('level', 9993), ('every', 9764), ('never', 9693), ('plant', 9637), ('sure', 9579), ('around', 9314), ('seem', 9229), ('start', 9194), ('enemy', 9028), ('fun', 8899), ('day', 8860), ('maybe', 8860), ('long', 8838), ('yeah', 8790), ('always', 8714), ('love', 8573), ('keep', 8405), ('best', 8274), ('squid', 8266), ('probably', 8227), ('two', 8167), ('someone', 8163), ('help', 8083), ('great', 7982), ('hit', 7960), ('happen', 7927), ('super', 7895), ('turf', 7855), ('last', 7802), ('many', 7778), ('second', 7772), ('run', 7710), ('change', 7653), ('splat', 7466), ('bomb', 7418), ('fire', 7401), ('shot', 7383), ('chomper', 7366), ('rise', 7224), ('pack', 7185), ('high', 7147), ('jump', 7124), ('lose', 7091), ('least', 7071), ('end', 7017), ('hard', 6987), ('variant', 6979), ('close', 6966), ('roller', 6928), ('easy', 6890), ('main', 6846), ('problem', 6734), ('already', 6690), ('class', 6629), ('enough', 6595)]
# Top E bigrams: [(('NUM', 'NUM'), 35257), (('turf', 'war'), 4299), (('level', 'NUM'), 3423), (('NUM', 'second'), 3162), (('NUM', 'damage'), 2691), (('NUM', 'hour'), 2583), (('pretty', 'much'), 2214), (('splat', 'zone'), 2072), (('NUM', 'pack'), 1844), (('tower', 'control'), 1580), (('NUM', 'gal'), 1571), (('NUM', 'point'), 1563), (('close', 'range'), 1556), (('long', 'range'), 1548), (('make', 'sense'), 1512), (('super', 'brainz'), 1490), (('burst', 'bomb'), 1486), (('around', 'NUM'), 1483), (('motion', 'control'), 1465), (('NUM', 'minute'), 1460), (('NUM', 'player'), 1404), (('day', 'NUM'), 1399), (('voice', 'chat'), 1354), (('swim', 'speed'), 1317), (('take', 'NUM'), 1295), (('NUM', 'kill'), 1291), (('single', 'player'), 1283), (('make', 'sure'), 1282), (('NUM', 'coin'), 1266), (('rank', 'NUM'), 1260), (('NUM', 'year'), 1237), (('win', 'NUM'), 1135), (('foot', 'soldier'), 1128), (('pretty', 'sure'), 1115), (('splash', 'wall'), 1100), (('ink', 'saver'), 1099), (('damage', 'NUM'), 1075), (('anyone', 'else'), 1041), (('turf', 'takeover'), 1028), (('use', 'NUM'), 1027), (('last', 'night'), 1019), (('run', 'speed'), 1011), (('URL', 'NUM'), 1009), (('URL', 'URL'), 1007), (('max', 'rank'), 986), (('NUM', 'day'), 961), (('least', 'NUM'), 956), (('NUM', 'match'), 956), (('plant', 'zombie'), 928), (('NUM', 'URL'), 926), (('fire', 'rate'), 926), (('URL', 'day'), 926), (('NUM', 'shot'), 879), (('super', 'jump'), 868), (('pvz', 'NUM'), 822), (('bos', 'hunt'), 822), (('NUM', 'win'), 815), (('splash', 'damage'), 810), (('carbon', 'roller'), 810), (('kill', 'NUM'), 808), (('splat', 'bomb'), 796), (('last', 'NUM'), 786), (('NUM', 'million'), 784), (('NUM', 'health'), 783), (('ninja', 'squid'), 778), (('killer', 'wail'), 772), (('make', 'NUM'), 752), (('buy', 'NUM'), 742), (('every', 'single'), 741), (('lose', 'NUM'), 737), (('super', 'commando'), 732), (('NUM', 'month'), 731), (('say', 'NUM'), 730), (('toxic', 'pea'), 721), (('bomb', 'rush'), 708), (('new', 'character'), 707), (('amp', 'NUM'), 704), (('NUM', 'sub'), 701), (('work', 'well'), 691), (('sea', 'snail'), 690), (('warfare', 'NUM'), 685), (('everyone', 'else'), 685), (('electro', 'pea'), 684), (('unicorn', 'chomper'), 680), (('give', 'NUM'), 679), (('ink', 'resistance'), 675), (('ink', 'recovery'), 674), (('NUM', 'main'), 668), (('little', 'bit'), 662), (('NUM', 'character'), 658), (('toxic', 'brainz'), 657), (('moray', 'tower'), 654), (('every', 'NUM'), 645), (('take', 'long'), 637), (('need', 'NUM'), 637), (('NUM', 'rank'), 636), (('camo', 'cactus'), 628), (('legendary', 'character'), 625), (('enemy', 'ink'), 625), (('agent', 'pea'), 621)]

# %%
plot_ngrams(unigrams_E[1:], bigrams_E[1:], "E")

# %%
plot_ngrams_hor(unigrams_E[1:20], bigrams_E[1:20], "E")
